# %% [markdown]
# <a href="https://colab.research.google.com/github/FatimahAzzahra04/2026_PrakAlpro_A_2611531001/blob/main/LapPrak_ALpro1_2611531001_FatimahAzzahra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#
# **LAPORAN TUGAS PRAKTIKUM**
#
#
# **“PENGENALAN PYTHON, VSCODE DAN KONEKSI KE GITHUB”**
#
# **Disusun Oleh :**
#
# **Fatimah Azzahra**
#
# **2611531001**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Avero**
#
# <br>
#
#  <img src="https://upload.wikimedia.org/wikipedia/commons/0/01/Logo_Unand.svg?utm_source=id.wikipedia.org&utm_campaign=index&utm_content=original" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum Pertemuan 1 (Pengenalan Python, VSCode dn koneksi ke GitHub) yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Algoritma dan Pemograman. Praktikum ini berfokus pada pengenalan aplikasi Python, VSCode dan juga koneksi ke GitHub.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung Proses pembuatan kode program menggunakan Python di VSCode dan mengelola repositori proyek melalui GitHub pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Perkembangan industri teknologi yang pesat memicu tingginya kebutuhan akan pemrosesan data, otomatisasi, dan pembuatan aplikasi secara efisien. Dalam konteks ini, Python menjadi pilihan utama bagi banyak pengguna terutama mahasiswa karena memiliki sintaks yang sederhana, mudah dipelajari, serta serbaguna untuk berbagai bidang seperti kecerdasan buatan, analisis data, hingga pengembangan web. Namun, penulisan kode yang efektif tidak cukup hanya mengandalkan bahasa pemrograman, diperlukan text editor yang andal seperti Visual Studio Code (VS Code).
#
# VS Code menyediakan lingkungan pengembangan modern yang dilengkapi fitur debugging, extension yang kaya, serta kemudahan navigasi kode. Di sisi lain, proyek perangkat lunak masa sekarang menuntut adanya pencatatan riwayat perubahan kode yang terstruktur serta ruang untuk berkolaborasi.
#
# GitHub hadir sebagai platform berbasis Git yang memungkinkan pengembang menyimpan cadangan kode di awan, mengelola versi aplikasi, dan bekerja sama dalam tim secara global. Integrasi antara Python, VS Code, dan koneksi ke GitHub menciptakan alur kerja (developer workflow) standar industri yang siap mendukung produktivitas secara maksimal.
# ## 1.2 Tujuan
# 1.Praktikan dapat memahami dasar-dasar bahasa pemrograman Python.
# 2.Mengetahui cara membuat dan menjalankan program Python menggunakan VS Code.
# 3.Memahami dasar penggunaan GitHub untuk menyimpan dan mengelola kode program.
# 4.Mengetahui hubungan antara VS Code, Python, dan GitHub dalam proses pengembangan program.
# ## 1.3 Manfaat
# 1.Praktikan dapat memahami dasar-dasar bahasa pemrograman Python.
# 2.Praktikan dapat menggunakan VS Code untuk membuat, mengedit, dan menjalankan program Python.
# 3.Praktikan dapat memahami penggunaan GitHub sebagai media penyimpanan dan pengelolaan kode program.
# 4.Praktikan dapat mengetahui cara menghubungkan proyek yang dibuat melalui VS Code dengan GitHub.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
#
# 1. Python: Bahasa pemrograman tingkat tinggi yang sederhana, mudah dipelajari, dan serbaguna untuk berbagai kebutuhan seperti pemrosesan data, kecerdasan buatan, hingga pengembangan web.
#
# 2. VS Code: Perangkat lunak penyunting kode (text editor) gratis dan ringan dari Microsoft yang dilengkapi fitur modern untuk menulis, menguji, serta memperbaiki kode program.
#
# 3. GitHub: Platform berbasis cloud untuk menyimpan, mengelola versi kode, dan memfasilitasi kolaborasi proyek pemrograman berbasis Git.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "A_2611531001"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
print("Hello World")
print("Nama saya adalah Zahra")

# %% [markdown]
# **Penjelasan :**
# Penjelasan Kode Program
#
# 1. Bagian kode ini **`print("Hello World")`**
#    Digunakan untuk menampilkan teks **“Hello world”** ke layar.
#
# 2. Bagian kode ini **`print("Nama saya adalah Zahra")`**
#    Digunakan untuk menampilkan teks **“Nama Saya adalah Zahra”** ke layar.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa Python, Visual Studio Code (VS Code), dan GitHub merupakan beberapa perangkat yang saling mendukung dalam proses pengembangan program. Python digunakan sebagai bahasa pemrograman untuk membuat dan menjalankan program, sedangkan VS Code digunakan sebagai lingkungan untuk menulis, mengedit, serta menjalankan kode Python dengan lebih mudah. Selanjutnya, GitHub digunakan sebagai platform untuk menyimpan, mengelola, dan membagikan kode program secara daring.
#
# Melalui praktikum ini, mahasiswa dapat memahami dasar penggunaan Python, mengenal fitur-fitur VS Code, serta mengetahui cara menghubungkan dan mengunggah proyek ke GitHub. Penggunaan ketiga teknologi tersebut dapat membantu membuat proses pemrograman menjadi lebih terstruktur, memudahkan penyimpanan dan pengelolaan kode, serta mendukung proses kolaborasi dalam pengembangan perangkat lunak.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation. (2023). Python 3.11.9 documentation. https://docs.python.org/3.11/
#
# [2] Microsoft. (2024). Visual Studio Code Documentation. Diakses dari https://code.visualstudio.com/docs
#
# [3] GitHub, Inc. (2024). GitHub Docs. Diakses dari https://docs.github.com
#
# [4] Downey, A. B. (2015). Think Python: How to Think Like a Computer Scientist (2nd ed.). O'Reilly Media.
#
# [5] Matthes, E. (2019). Python Crash Course: A Hands-On, Project-Based Introduction to Programming (2nd ed.). No Starch Press.
