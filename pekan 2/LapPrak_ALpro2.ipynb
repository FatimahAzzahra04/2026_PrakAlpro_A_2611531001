# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
#
# **“TYPE DATA DAN VARIABEL”**
#
# **Disusun Oleh :**
#
# **Fatimah Azzahra**
#
# **2611531001**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Avero**
#
# <br>
#
#  <img src="https://upload.wikimedia.org/wikipedia/commons/0/01/Logo_Unand.svg?utm_source=id.wikipedia.org&utm_campaign=index&utm_content=original" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum Pertemuan 2 (Type data dan Variabel) yang telah dilaksanakan sebagai pertemuan ke-2 untuk mata kuliah Praktikum Algoritma dan Pemograman. Praktikum ini berfokus pada pengenalan dan cara penggunaan variabel dan type data seperti: Boolean, String, Numerik,Konstanta dan Penggunaan Input dalam python.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung Penggunaan variabel dan type data yang akan digunakan untuk program.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Pemrograman komputer merupakan salah satu kemampuan dasar yang sangat penting untuk dikuasai dalam era digital saat ini. Salah satu konsep fundamental yang wajib dipahami sebelum mempelajari algoritma yang lebih kompleks adalah konsep variabel dan tipe data. Variabel berfungsi sebagai wadah untuk menyimpan suatu nilai yang dapat digunakan dan diproses selama program dijalankan, sedangkan tipe data menentukan jenis nilai yang dapat disimpan dalam variabel tersebut, seperti angka (numerik), teks(string), nilai benar/salah(boolean), nama input maupun nilai tetap(konstanta).
#
# Bahasa pemrograman Python dipilih dalam praktikum ini karena memiliki sintaks yang sederhana, mudah dipahami oleh pemula, serta bersifat dynamically typed, artinya tipe data suatu variabel ditentukan secara otomatis oleh Python berdasarkan nilai yang diberikan tanpa perlu dideklarasikan secara eksplisit seperti pada bahasa pemrograman lain. Meskipun demikian, pemahaman yang mendalam mengenai tipe data tetap diperlukan agar program yang dibuat dapat berjalan dengan benar dan efisien.
#
# Melalui praktikum ini, mahasiswa diajak untuk mempraktikkan langsung penggunaan berbagai tipe data, yaitu string untuk menyimpan data biodata diri, boolean untuk menentukan status kelulusan, numerik (integer, float, dan complex) untuk melakukan perhitungan matematis, serta konstanta yang nilainya tidak dapat diubah selama program berjalan, seperti nilai PI dalam perhitungan luas lingkaran.
#
# ## 1.2 Tujuan
# 1.	Memahami konsep dasar variabel dan tipe data dalam bahasa pemrograman Python.
# 2.	Mampu membuat dan menggunakan variabel dengan tipe data string untuk menyimpan data biodata diri.
# 3.	Mampu membuat dan menggunakan variabel dengan tipe data boolean untuk melakukan pengecekan kondisi logika.
# 4.	Mampu membuat dan menggunakan variabel dengan tipe data numerik (integer, float, dan complex) beserta fungsi type() untuk memeriksa jenis tipe datanya.
# 5.	Mampu mengimplementasikan input dari pengguna serta melakukan konversi tipe data (type casting) dalam suatu program sederhana.
# 6.	Mampu menerapkan konsep konstanta (constant) menggunakan modul typing pada Python.
#
# ## 1.3 Manfaat
# 1. Menambah pemahaman dan keterampilan praktis mahasiswa dalam menulis kode program menggunakan Python, khususnya terkait variabel dan tipe data.
# 2. Melatih kemampuan berpikir logis dan sistematis dalam menyelesaikan suatu permasalahan melalui program komputer.
# 3. Memberikan dasar yang kuat sebelum mempelajari materi pemrograman yang lebih lanjut, seperti struktur kontrol, perulangan, dan fungsi.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
#
# Dalam bahasa pemrograman Python, variabel adalah suatu nama yang digunakan untuk merujuk pada suatu lokasi memori tempat sebuah nilai disimpan. Python bersifat dynamically typed language, sehingga tipe data suatu variabel tidak perlu dideklarasikan secara eksplisit, melainkan ditentukan secara otomatis berdasarkan nilai yang diberikan pada saat penugasan (assignment). Berikut adalah penjelasan mengenai beberapa tipe data dasar yang digunakan dalam praktikum ini.
#
# 1. Tipe Data Numerik
#
# Tipe data numerik pada Python terbagi menjadi tiga jenis utama, yaitu:
#
# a.	Integer (int): bilangan bulat tanpa mengandung angka desimal, contohnya 100.
#
# b.	Float: bilangan pecahan atau bilangan yang mengandung angka di belakang koma, contohnya 10.2345.
#
# c.	Complex: bilangan kompleks yang terdiri dari bagian real dan bagian imajiner yang ditandai dengan huruf j, contohnya 100+3j.
#
# Untuk memeriksa jenis tipe data dari suatu variabel, Python menyediakan fungsi bawaan type() yang akan mengembalikan nama kelas (class) dari tipe data variabel tersebut.
#
# 2. Tipe Data String
#
# String merupakan tipe data yang digunakan untuk menyimpan kumpulan karakter atau teks, seperti nama, alamat, atau kalimat. Dalam Python, string dapat dituliskan menggunakan tanda kutip tunggal ('...'), tanda kutip ganda ("..."), maupun tanda kutip tiga ("""...""") yang biasa digunakan untuk menuliskan string dengan format lebih dari satu baris (multiline string).
#
# 3. Tipe Data Boolean
#
# Boolean adalah tipe data yang hanya memiliki dua kemungkinan nilai, yaitu True (benar) atau False (salah). Tipe data ini umumnya digunakan sebagai hasil dari suatu ekspresi logika atau perbandingan (comparison), misalnya untuk menentukan apakah suatu nilai lebih besar, lebih kecil, atau sama dengan nilai lain, serta digunakan dalam pengambilan keputusan pada struktur percabangan seperti if.
#
# 4. Fungsi input
#
#  Fungsi input() untuk menerima masukan dari pengguna. Perlu diperhatikan bahwa nilai yang dihasilkan oleh fungsi input() selalu bertipe string, sehingga apabila nilai tersebut akan digunakan dalam operasi matematis (seperti perkalian atau penjumlahan), maka nilai tersebut harus dikonversi (type casting) terlebih dahulu ke tipe data yang sesuai menggunakan fungsi seperti int() atau float().
#
# 5. Konstanta (Constant)
#
# Konstanta adalah suatu variabel yang nilainya bersifat tetap dan tidak boleh diubah selama program dijalankan. Python secara bawaan sebenarnya tidak memiliki mekanisme khusus untuk membuat konstanta sejati, karena semua variabel pada dasarnya dapat diubah nilainya. Namun, Python menyediakan modul typing dengan tipe Final yang dapat digunakan sebagai penanda (annotation) bahwa suatu variabel dimaksudkan untuk tidak diubah nilainya.
#
# Jika suatu variabel yang ditandai Final diubah, maka type checker (seperti mypy) akan memberikan peringatan, meskipun Python interpreter sendiri tidak akan menghentikan eksekusi program. Konvensi penulisan nama konstanta pada umumnya menggunakan huruf kapital seluruhnya, misalnya PI.

# %% [markdown]
# ## 2.2 Kode Program
#
# 2.2.1 Program "Numerik_2611531001"

# %%
#create a variable with integer value.
a_1001=100
print("The type of variable having value",a_1001,"is",type(a_1001))

#acreate a variable with float value.
b_1001=10.2345
print("The type of variable having value", b_1001,"is",type(b_1001))

#acreate a variable with complex value.
c_1001=100+3j
print ("The type of variable having value ",c_1001,"is",type(c_1001))
# Out:
# The type of variable having value 100 is <class 'int'>
# The type of variable having value 10.2345 is <class 'float'>
# The type of variable having value  (100+3j) is <class 'complex'>

# %% [markdown]
# Penjelasan :
# Tipe Data Angka:
#
# a_1001 = 100 adalah bilangan bulat (Integer).
#
# b_1001 = 10.2345 adalah bilangan desimal (Float).
#
# c_1001 = 100+3j adalah bilangan kompleks (Complex).

# %% [markdown]
# 2.2.2 Program "String_2611531001"

# %%
nama_1001 = "FatimahAzzahra"
jenis_kelamin_1001 = 'P'
alamat_1001 ="""
   Asrama Unand
   kec.pauh
   kota Padang
"""
agama_1001 = 'Islam'
print("Nama saya adalah: ", nama_1001)
print("Jenis kelamin saya adalah: ", jenis_kelamin_1001)
print("Alamat saya adalah: ", alamat_1001)
print("Agama saya adalah: ", agama_1001)
# Out:
# Nama saya adalah:  FatimahAzzahra
# Jenis kelamin saya adalah:  P
# Alamat saya adalah:
#    Asrama Unand
#    kec.pauh
#    kota Padang
#
# Agama saya adalah:  Islam

# %% [markdown]
# Penjelasan:
# 1. Inisialisasi Variabel: Menyimpan data diri seperti nama_1001, jenis_kelamin_1001, dan agama_1001 menggunakan format string.
#
# 2. Multiline String: Variabel alamat_1001 menggunakan tanda petik tiga (""") untuk menyimpan teks multi-baris (alamat lengkap).

# %% [markdown]
# 2.2.3 Program "Boolean_2611531001"

# %%
is_lulus_1001 = True
is_cumlaude_1001 = True

# Menggunakan Boolean
nilai_1001 = 85
batas_lulus_1001 = 75

#Menentukan nilai Boolean dari kondisi
status_kelulusan_1001 = nilai_1001 >= batas_lulus_1001  # Hasilnya akan True

print("=== Check Kelulusan ===")
print("Nilai:", nilai_1001)
print("Apakah lulus?:", status_kelulusan_1001)
if is_lulus_1001 and is_cumlaude_1001:
    print("Selamat, Anda lulus dengan predikat Cum Laude!")
# Out:
# === Check Kelulusan ===
# Nilai: 85
# Apakah lulus?: True
# Selamat, Anda lulus dengan predikat Cum Laude!

# %% [markdown]
# Penjelasan:
#
# 1. Inisialisasi Variabel: is_lulus_1001 dan is_cumlaude_1001 bernilai True. nilai_1001 diisi 85 dan batas_lulus_1001 diisi 75.
#
# 2. Evaluasi Kondisi: Variabel status_kelulusan_1001 mengecek apakah nilai lebih besar atau sama dengan batas lulus (85 >= 75), yang menghasilkan nilai True.

# %% [markdown]
# 2.2.4 Program "nama input_2611531001"

# %%
panjang_1001= input('Masukkan nilai panjang: ')
lebar_1001 = input('Masukkan nilai lebar: ')
luas_1001 = int(panjang_1001) * int(lebar_1001)
print("Luas =", luas_1001)
# Out:
# Luas = 56

# %% [markdown]
# Penjelasan:
# 1. Input Data: Menerima masukan dari pengguna untuk nilai panjang dan lebar melalui fungsi input().
#
# 2. Konversi & Operasi: Mengonversi input teks menjadi bilangan bulat menggunakan int(), lalu mengalikannya untuk menghitung luas.

# %% [markdown]
# 2.2.5 Program "Konstanta_2611531001"

# %%
from typing import Final
PI: Final = 3.14
print("pI: %f" % (PI))
jari_1001 = float(input('Masukkan nilai jari-jari:'))
luas_1001 = PI * jari_1001 * jari_1001
print("Luas lingkaran dengan jari-jari %.2f adalah %.2f" % (jari_1001, luas_1001))
# Out:
# pI: 3.140000
# Luas lingkaran dengan jari-jari 7.00 adalah 153.86

# %% [markdown]
# Penjelasan:
# 1. Mendefinisikan konstanta PI bernilai 3.14 (catatan: kode pada gambar menggunakan terjemahan otomatis "dari pengetikan impor Final" yang aslinya from typing import Final).
#
# 2. Input & Operasi: Meminta masukan jari-jari dari pengguna, mengonversinya ke desimal (float), lalu menghitung luas lingkaran (Luas = PI x r**).

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="images/soal_tugas.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "Fatimah Azzahra_2611531001"

# %%
print ("=== SISTEM REGISTRASI PRAKTIKAN ALPRO 2026 ===")

nama_1001 = input(str("Masukkan Nama Mahasiswa : "))
jenis_kelamin_1001 = input ("Masukkan Jenis Kelamin (L/P) : ")
umur_1001 = int(input("Masukkan Umur : "))
skor_tes_awal_1001 = float(input("Masukkan Skor Tes Awal : "))

print("\n=== DATA PRAKTIKAN & HASIL PEMERIKSAAN ===")

alamat_1001 = """
Andalas Residance,
Limau Manis, Kecamatan Pauh, Kota Padang, Sumatera Barat, Indonesia ,
Kota Padang """
id_token_sinyal = 100+3j

print("Nama Mahasiswa :", nama_1001, "|", "Tipe :", type(nama_1001))
print("Jenis Kelamin :", jenis_kelamin_1001, "|", "Tipe :", type(jenis_kelamin_1001))
print("Alamat Domisili :", alamat_1001, "|", "Tipe :", type(alamat_1001))
print("Umur :", umur_1001, "tahun", "|", "Tipe :", type(umur_1001))
print("Skor Tes Awal :", skor_tes_awal_1001, "|", "Tipe :", type (skor_tes_awal_1001))
print("ID Token Sinyal :", id_token_sinyal, "|", "Tipe :", type (id_token_sinyal))

print("\n=== STATUS KELULUSAN PRAKTIKUM ===")

batas_1001 = 75.0

print("Batas Minimum Nilai:", batas_1001)
if skor_tes_awal_1001 >= batas_1001:
    hasil_1001 = True
else:
    hasil_1001 = False
print("Apakah dinyatakan lulus?:", hasil_1001, "|", "Tipe :", type (hasil_1001))
# Out:
# === SISTEM REGISTRASI PRAKTIKAN ALPRO 2026 ===
#
# === DATA PRAKTIKAN & HASIL PEMERIKSAAN ===
# Nama Mahasiswa : fatimah azzahra | Tipe : <class 'str'>
# Jenis Kelamin : P | Tipe : <class 'str'>
# Alamat Domisili :
# Andalas Residance,
# Limau Manis, Kecamatan Pauh, Kota Padang, Sumatera Barat, Indonesia ,
# Kota Padang  | Tipe : <class 'str'>
# Umur : 18 tahun | Tipe : <class 'int'>
# Skor Tes Awal : 76.0 | Tipe : <class 'float'>
# ID Token Sinyal : (100+3j) | Tipe : <class 'complex'>
#
# === STATUS KELULUSAN PRAKTIKUM ===
# Batas Minimum Nilai: 75.0
# Apakah dinyatakan lulus?: True | Tipe : <class 'bool'>

# %% [markdown]
# Penjelasan:
# program tugas ini memiliki penjelasan
#
# 1. Judul Program
# Program diawali dengan judul “Sistem Registrasi Praktikan Alpro 2026”.Digunakan untuk menunjukkan bahwa program berfungsi sebagai sistem registrasi praktikan.
#
# 2. Input Data Mahasiswa
# Pengguna diminta memasukkan nama mahasiswa.
# Pengguna memasukkan jenis kelamin dengan pilihan L/P.
# Pengguna memasukkan umur dalam bentuk bilangan bulat.
# Pengguna memasukkan skor tes awal yang dapat berupa bilangan desimal.
#
# 3. Penyimpanan Data
# Data yang dimasukkan disimpan ke dalam variabel.Setiap variabel memiliki nama yang berbeda sesuai dengan data yang disimpan.
#
# 4. Data Alamat
# Program menyimpan alamat domisili mahasiswa.
# Alamat menggunakan tipe data string karena berupa teks.
# Alamat dapat ditulis dalam beberapa baris.
#
# 5. ID Token Sinyal
# Program memiliki data berupa 100+3j.
# Data tersebut merupakan contoh tipe data complex (bilangan kompleks).Bilangan kompleks terdiri dari bagian real dan bagian imajiner.
#
# 6. Menampilkan Data dan Tipe Data
# Program menampilkan kembali seluruh data yang telah dimasukkan.
# Program juga menampilkan tipe data dari setiap variabel.Fungsi type() digunakan untuk mengetahui tipe data tersebut.
#
# 7. Tipe Data yang Digunakan
# String (str) → nama, jenis kelamin, dan alamat.
# Integer (int) → umur.
# Float → skor tes awal dan batas minimum nilai.
# Complex → ID Token Sinyal.
# Boolean (bool) → hasil kelulusan.
#
# 8. Penentuan Batas Kelulusan
# Program menetapkan nilai minimum kelulusan sebesar 75,0. Nilai tersebut digunakan sebagai pembanding dengan skor tes awal.
#
# 9. Proses Menentukan Kelulusan
# Jika skor tes awal lebih besar atau sama dengan 75, mahasiswa dinyatakan lulus.Jika skor tes awal kurang dari 75, mahasiswa dinyatakan tidak lulus, proses ini menggunakan percabangan if-else.
#
# 10. Hasil Kelulusan
# Hasil kelulusan disimpan dalam bentuk Boolean.
# True berarti mahasiswa dinyatakan lulus.
# False berarti mahasiswa dinyatakan tidak lulus.
#
# 11. Kesimpulan
# Program ini digunakan untuk menginput, menyimpan, menampilkan, dan memeriksa data praktikan. Program juga memperkenalkan penggunaan berbagai tipe data Python serta percabangan untuk menentukan kelulusan.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilaksanakan mengenai tipe data dan variabel dalam bahasa pemrograman Python, dapat disimpulkan beberapa hal sebagai berikut:
#
# 1.	Variabel dalam Python dapat dideklarasikan secara langsung tanpa perlu menuliskan tipe data secara eksplisit, karena Python bersifat dynamically typed.
#
# 2.	Tipe data string digunakan untuk menyimpan data berupa teks, dan Python menyediakan string tiga kutip untuk menuliskan teks dengan format multi-baris, seperti pada kasus penulisan alamat.
#
# 3.	Tipe data boolean (True/False) sangat berguna untuk merepresentasikan hasil dari suatu kondisi logika atau perbandingan, dan sering digunakan sebagai dasar pengambilan keputusan pada struktur percabangan if.
#
# 4.	Tipe data numerik pada Python terdiri atas integer, float, dan complex, yang masing-masing dapat diperiksa jenisnya menggunakan fungsi bawaan type().
#
# 5.	Fungsi input() selalu menghasilkan nilai bertipe string, sehingga diperlukan proses konversi tipe data (type casting) menggunakan fungsi seperti int() atau float() apabila nilai tersebut akan digunakan dalam operasi aritmatika.
# 6.	Konstanta dapat diterapkan pada Python menggunakan anotasi Final dari modul typing, yang menandai bahwa suatu variabel dimaksudkan untuk tidak diubah nilainya selama program berjalan.
# 7.	Pemahaman yang baik mengenai variabel dan tipe data merupakan fondasi penting yang akan sangat membantu dalam mempelajari konsep pemrograman yang lebih kompleks di masa

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation. (2023). Python 3.11.9 documentation.
#
# [2] Microsoft. (2024). Visual Studio Code Documentation. Diakses dari https://code.visualstudio.com/docs
#
# [3] GitHub, Inc. (2024). GitHub Docs. Diakses dari https://docs.github.com
#
# [4] Downey, A. (2015). Think Python: How to Think Like a Computer Scientist (2nd ed.). O'Reilly Media. Diakses dari https://greenteapress.com/wp/think-python-2e/
#
# [5] Lutz, M. (2013). Learning Python (5th ed.). O'Reilly Media. Diakses dari https://www.oreilly.com/library/view/learning-python-5th/9781449355722/
#
# [6] W3Schools. (n.d.). Python Variables and Data Types. Diakses pada 9 September 2026, dari https://www.w3schools.com/python/python_variables.asp
#
# [7] GeeksforGeeks. (n.d.). Python Data Types. Diakses pada 9 September 2026, dari https://www.geeksforgeeks.org/python-data-types/
